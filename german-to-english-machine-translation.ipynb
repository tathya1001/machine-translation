# %%
# !pip install torchtext==0.15.2 torch==2.0.1 numpy 'portalocker>=2.0.0'
# Out:
# Requirement already satisfied: torchtext==0.15.2 in /usr/local/lib/python3.10/dist-packages (0.15.2)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: portalocker>=2.0.0 in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.15.2) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.15.2) (2.32.3)
# Requirement already satisfied: torchdata==0.6.1 in /usr/local/lib/python3.10/dist-packages (from torchtext==0.15.2) (0.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.6.1->torchtext==0.15.2) (2.2.3)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1) (18.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.15.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.15.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.15.2) (2024.12.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1) (1.3.0)

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torchtext.datasets import multi30k, Multi30k
from typing import Iterable, List
from torch.nn.utils.rnn import pad_sequence
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting de-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.7.0/de_core_news_sm-3.7.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 104.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from de-core-news-sm==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.10.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2024.12.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
if torch.cuda.is_available():
    device=torch.device(type='cuda',index=0)
else:
    device=torch.device(type='cpu',index=0)
print(device)
# Out:
# cuda:0

# %%
multi30k.URL["train"] = "https://raw.githubusercontent.com/neychev/small_DL_repo/master/datasets/Multi30k/training.tar.gz"
multi30k.URL["valid"] = "https://raw.githubusercontent.com/neychev/small_DL_repo/master/datasets/Multi30k/validation.tar.gz"

SRC_LANGUAGE = 'de'
TGT_LANGUAGE = 'en'

# %%
de_tokenizer = get_tokenizer('spacy', language='de_core_news_sm')
en_tokenizer = get_tokenizer('spacy', language='en_core_web_sm')

# %%
def yield_tokens(data_iter: Iterable, language: str) -> List[str]:
    if language=='de':
        for data_sample in data_iter:
            yield de_tokenizer(data_sample[0])
    elif language=='en':
        for data_sample in data_iter:
            yield en_tokenizer(data_sample[1])

UNK_IDX, PAD_IDX, BOS_IDX, EOS_IDX = 0, 1, 2, 3

special_symbols = ['<unk>', '<pad>', '<bos>', '<eos>']

# build vocab for German
train_iter = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))

vocab_de=build_vocab_from_iterator(yield_tokens(train_iter, 'de'),
                                                    min_freq=1,
                                                    specials=special_symbols,
                                                    special_first=True)
vocab_de.set_default_index(UNK_IDX)


# build vocab for English
train_iter = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
vocab_en=build_vocab_from_iterator(yield_tokens(train_iter, 'en'),
                                                    min_freq=1,
                                                    specials=special_symbols,
                                                    special_first=True)
vocab_en.set_default_index(UNK_IDX)

# %%
sentence = "Ein Hund springt in die Luft, um eine orange Frisbeescheibe zu fangen."
tokens = sentence.split()
token_ids = [vocab_de.get_stoi().get(word, UNK_IDX) for word in tokens]  # Use get_stoi() for access

# %%
print(token_ids)
# Out:
# [5, 33, 71, 7, 19, 0, 66, 18, 806, 1400, 29, 0]

# %%
torch.save(vocab_de, 'vocab_de.pth')
torch.save(vocab_en, 'vocab_en.pth')

# %%
print(type(vocab_en))
print("English Vocab Length:",vocab_en.__len__())
print("German Vocab Length:",vocab_de.__len__())
# Out:
# <class 'torchtext.vocab.vocab.Vocab'>
# English Vocab Length: 10837
# German Vocab Length: 19214

# %%
def collate_fn(batch):
    src_batch, tgt_batch, src_len = [], [], []
    for src_sample, tgt_sample in batch:

        src_sample = src_sample.rstrip("\n")  # string
        tgt_sample = tgt_sample.rstrip("\n")

        src_tokens = de_tokenizer(src_sample)  # sentence to list of word tokens
        tgt_tokens = en_tokenizer(tgt_sample)

        src_ids = vocab_de(src_tokens)  # list of word tokens to list of ids
        tgt_ids = vocab_en(tgt_tokens)

        src_ids.append(EOS_IDX)  # append <EOS> to list
        tgt_ids.append(EOS_IDX)

        tgt_ids.insert(0, BOS_IDX)  # insert <BOS> at the beginning of list

        src_len.append(len(src_ids))  # [batch_size,]

        src_tensor = torch.tensor(src_ids)  # [seq_len_src]
        tgt_tensor = torch.tensor(tgt_ids)  # [seq_len_tgt]

        src_batch.append(src_tensor)  # list of tensors
        tgt_batch.append(tgt_tensor)

    src_batch = pad_sequence(src_batch, padding_value=PAD_IDX, batch_first=True)  # [batch_size, max_seq_len_src]
    tgt_batch = pad_sequence(tgt_batch, padding_value=PAD_IDX, batch_first=True)  # [batch_size, max_seq_len_tgt]
    return src_batch, tgt_batch, src_len

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embed_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.e = nn.Embedding(input_size, embed_size)  # input_size: vocab_size, embed_size: embedding dimension
        self.dropout = nn.Dropout(dropout_p)
        self.gru = nn.GRU(embed_size, hidden_size, batch_first=True)  # embed_size: input size, hidden_size: output size

    def forward(self, x, lengths):
        x = self.e(x)  # x: [batch_size, seq_len] -> output: [batch_size, seq_len, embed_size]
        x = self.dropout(x)
        x = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)  # [batch_size, seq_len, embed_size]

        outputs, hidden = self.gru(x)  # outputs: [batch_size, seq_len, hidden_size], hidden: [1, batch_size, hidden_size]
        outputs, _ = pad_packed_sequence(outputs, batch_first=True)  # outputs: [batch_size, seq_len, hidden_size]

        return outputs, hidden

# %%
class Decoder(nn.Module):
    def __init__(self, output_size, embed_size, hidden_size):
        super().__init__()
        self.e = nn.Embedding(output_size, embed_size)
        self.dropout = nn.Dropout()
        self.gru = nn.GRU(embed_size + hidden_size, hidden_size, batch_first=True)
        self.lin = nn.Linear(hidden_size, output_size)
        self.lsoftmax = nn.LogSoftmax(dim=-1)

    def forward(self, x, context, prev_hidden):
        x = self.e(x)  # x: [batch_size, seq_len] -> [batch_size, seq_len, embed_size]
        x = self.dropout(x)
        x = torch.cat((x, context), dim=2)  # [batch_size, seq_len, embed_size + hidden_size]

        output, hidden = self.gru(x, prev_hidden)  # output: [batch_size, seq_len, hidden_size], hidden: [1, batch_size, hidden_size]

        y = self.lin(output)  # y: [batch_size, seq_len, output_size]
        y = self.lsoftmax(y)  # y: [batch_size, seq_len, output_size]

        return y, hidden

# %%
class Bahdanau_Attention(nn.Module):
    def __init__(self,encoder_hidden_size,decoder_hidden_size,new_hidden_size):
        super().__init__()
        self.eh2nh=nn.Linear(in_features=encoder_hidden_size, out_features=new_hidden_size)
        self.dh2nh=nn.Linear(in_features=decoder_hidden_size, out_features=new_hidden_size)
        self.score=nn.Linear(in_features=new_hidden_size, out_features=1)

    def forward(self,query,keys):
        query=self.dh2nh(query)
        keys=self.eh2nh(keys)
        att_score=self.score(torch.tanh(query.permute(1,0,2) + keys))
        att_score=att_score.squeeze(2).unsqueeze(1)
        att_weights=F.softmax(att_score, dim=-1)
        context=torch.bmm(att_weights,keys)


        return context, att_weights

# %%
def train_one_epoch(train_dataloader):
    encoder.train()
    decoder.train()
    total_loss = 0


    for idx, (src_ids, tgt_ids, src_len) in enumerate(train_dataloader):
        src_ids = src_ids.to(device)  # src_ids: [batch_size, seq_len_src]
        tgt_ids = tgt_ids.to(device)  # tgt_ids: [batch_size, seq_len_tgt]

        encoder_outputs, encoder_hidden = encoder(src_ids, src_len)  # encoder_outputs: [batch_size, seq_len_src, hidden_size], encoder_hidden: [1, batch_size, hidden_size]
        decoder_hidden = encoder_hidden  # decoder_hidden: [1, batch_size, hidden_size]

        predictions = []

        for j in range(0, tgt_ids.shape[1] - 1):  # tgt_ids.shape[1] -> seq_len_tgt
            context, attention_weights = ba(decoder_hidden, encoder_outputs)  # context: [batch_size, seq_len_src, hidden_size]

            probs, decoder_hidden = decoder(tgt_ids[:, j].unsqueeze(1), context, decoder_hidden)  # probs: [batch_size, 1, output_size], decoder_hidden: [1, batch_size, hidden_size]
            predictions.append(probs)

        predictions_cat = torch.cat(predictions, dim=1)  # predictions_cat: [batch_size, seq_len_tgt - 1, output_size]
        predictions_reshaped = predictions_cat.view(-1, predictions_cat.shape[-1])  # predictions_reshaped: [batch_size * (seq_len_tgt - 1), output_size]

        target = tgt_ids[:, 1:]  # target: [batch_size, seq_len_tgt - 1]
        target = target.reshape(-1)  # target: [batch_size * (seq_len_tgt - 1)]

        loss = loss_fn(predictions_reshaped, target)
        total_loss += loss.item()

        opte.zero_grad()
        optd.zero_grad()
        optba.zero_grad()

        loss.backward()

        opte.step()
        optd.step()
        optba.step()

    return total_loss / (idx + 1)

# %%
def test_one_epoch(epoch, n_epochs, test_dataloader):
    encoder.eval()
    decoder.eval()
    ba.eval()
    total_loss = 0



    with torch.no_grad():
        for i, (src_ids, tgt_ids, src_len) in enumerate(test_dataloader):
   
            src_ids = src_ids.to(device)  # [1, source seq_len]
            tgt_ids = tgt_ids.to(device)
            src_len = torch.tensor(src_len, dtype=torch.int64)

            enc_outputs, enc_hidden = encoder(src_ids, src_len)  # enc_outputs: [batch_size, src_len, hidden_size]
            dec_hidden = enc_hidden  # [1, batch_size, hidden_size]
            input_id = tgt_ids[:, 0]  # first token (BOS) [batch_size]
            yhats = []

            if epoch + 1 == n_epochs:
                pred_sentence = ""

            for j in range(1, tgt_ids.shape[1]):  # iterate for len(tgt_ids)-1
 
                # dec_hidden: [1, batch_size, hidden_size] -> [batch_size, 1, hidden_size]
                query = dec_hidden.transpose(0, 1)
                context, attention_weights = ba(query, enc_outputs)

                probs, dec_hidden = decoder(
                    input_id.unsqueeze(1),  # [batch_size, 1]
                    context,  # [batch_size, 1, hidden_size]
                    dec_hidden  # [1, batch_size, hidden_size]
                )
                yhats.append(probs)

                _, input_id = torch.topk(probs, 1, dim=-1)  # [batch_size, 1, 1]
                input_id = input_id.squeeze(1).squeeze(1)  # [batch_size]

                if epoch + 1 == n_epochs:
                    word = vocab_en.lookup_token(input_id.item())  # batch_size=1
                    pred_sentence += word + " "

                # if EOS token is predicted, stop generating further words
                if input_id.item() == EOS_IDX:
                    break

            if epoch + 1 == n_epochs:
                src_tokens = vocab_de.lookup_tokens(src_ids.tolist()[0])
                src_sentence = " ".join([token for token in src_tokens if token not in ["<pad>", "<eos>"]])
                gt_tokens = vocab_en.lookup_tokens(tgt_ids[:, 1:].tolist()[0])
                gt_sentence = " ".join([token for token in gt_tokens if token not in ["<pad>", "<eos>"]])
                print("-----------------------------------")
                print("Source Sentence:", src_sentence)
                print("Ground Truth:", gt_sentence)
                print("Prediction:", pred_sentence.strip())

            # cancatenate the predictions and calculate loss
            
            yhats_cat = torch.cat(yhats, dim=1)  # [batch_size, tgt_len-1, vocab_size]
            yhats_reshaped = yhats_cat.view(-1, yhats_cat.shape[-1])  # [batch_size*(tgt_len-1), vocab_size]
            gt = tgt_ids[:, 1:j+1].view(-1)  # [batch_size*(tgt_len-1)]

            loss = loss_fn(yhats_reshaped, gt)
            total_loss += loss.item()

        avg_loss = total_loss / (i + 1)
        return avg_loss

# %%
embed_size=300
hidden_size=512
batch_size=32

encoder_path = "encoder.pth"
decoder_path = "decoder.pth"
ba_path = "ba.pth"

# %%
train_iter = Multi30k(split='train', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
train_dataloader = DataLoader(train_iter, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)


test_iter = Multi30k(split='valid', language_pair=(SRC_LANGUAGE, TGT_LANGUAGE))
test_dataloader = DataLoader(test_iter, batch_size=1, collate_fn=collate_fn, shuffle=True)

# %%
encoder=Encoder(vocab_de.__len__(),embed_size,hidden_size).to(device) #translation-direction sensitive
decoder=Decoder(vocab_en.__len__(),embed_size,hidden_size).to(device) #translation-direction sensitive
ba=Bahdanau_Attention(hidden_size,hidden_size,hidden_size).to(device)

# uncomment below code to load already trained models

# encoder.load_state_dict(torch.load(encoder_path))
# decoder.load_state_dict(torch.load(decoder_path))
# ba.load_state_dict(torch.load(ba_path))

encoder.to(device)
decoder.to(device)
ba.to(device)

loss_fn=nn.NLLLoss(ignore_index=1).to(device)

lr=0.001

opte = optim.Adam(params=encoder.parameters(), lr=lr, weight_decay=0.001)
optd = optim.Adam(params=decoder.parameters(), lr=lr, weight_decay=0.001)
optba = optim.Adam(params=ba.parameters(), lr=lr)

# %%
# training with lr=0.001

n_epochs=20

for e in range(n_epochs):
    print("Epoch=",e+1, sep="", end=", ")
    print("Train Loss=", round(train_one_epoch(train_dataloader),4))
# Out:
# Epoch=1, Train Loss= 3.9296
# Epoch=2, Train Loss= 3.2449
# Epoch=3, Train Loss= 3.0491
# Epoch=4, Train Loss= 2.9085
# Epoch=5, Train Loss= 2.8034
# Epoch=6, Train Loss= 2.7458
# Epoch=7, Train Loss= 2.7034
# Epoch=8, Train Loss= 2.6744
# Epoch=9, Train Loss= 2.6412
# Epoch=10, Train Loss= 2.6224
# Epoch=11, Train Loss= 2.5972
# Epoch=12, Train Loss= 2.576
# Epoch=13, Train Loss= 2.5608
# Epoch=14, Train Loss= 2.5468
# Epoch=15, Train Loss= 2.5396
# Epoch=16, Train Loss= 2.5255
# Epoch=17, Train Loss= 2.5225
# Epoch=18, Train Loss= 2.5122
# Epoch=19, Train Loss= 2.5083
# Epoch=20, Train Loss= 2.5038

# %%
lr=0.0001

opte = optim.Adam(params=encoder.parameters(), lr=lr, weight_decay=0.001)
optd = optim.Adam(params=decoder.parameters(), lr=lr, weight_decay=0.001)
optba = optim.Adam(params=ba.parameters(), lr=lr)

# %%
# training with lr=0.0001

n_epochs=20

for e in range(n_epochs):
    print("Epoch=",e+1, sep="", end=", ")
    print("Train Loss=", round(train_one_epoch(train_dataloader),4))
# Out:
# Epoch=1, Train Loss= 2.3726
# Epoch=2, Train Loss= 2.2533
# Epoch=3, Train Loss= 2.1787
# Epoch=4, Train Loss= 2.1235
# Epoch=5, Train Loss= 2.085
# Epoch=6, Train Loss= 2.0543
# Epoch=7, Train Loss= 2.0294
# Epoch=8, Train Loss= 2.0107
# Epoch=9, Train Loss= 1.9919
# Epoch=10, Train Loss= 1.9798
# Epoch=11, Train Loss= 1.9657
# Epoch=12, Train Loss= 1.9565
# Epoch=13, Train Loss= 1.9457
# Epoch=14, Train Loss= 1.937
# Epoch=15, Train Loss= 1.927
# Epoch=16, Train Loss= 1.9191
# Epoch=17, Train Loss= 1.9144
# Epoch=18, Train Loss= 1.9071
# Epoch=19, Train Loss= 1.9001
# Epoch=20, Train Loss= 1.8969

# %%
n_epochs=1

for e in range(n_epochs):
    print("Epoch=",e+1, sep="", end=", ")
    print("Eval Loss=",round(test_one_epoch(e,n_epochs, test_dataloader),4))
# Out:
# Epoch=1, -----------------------------------
# Source Sentence: Ein sitzender Mann arbeitet mit seinen Händen .
# Ground Truth: A seated man is working with his hands .
# Prediction: A man is sitting on his man is using his
# -----------------------------------
# Source Sentence: Eine Frau in einem schwarzen Kleid schiebt einen Wagen mit <unk> einen gepflasterten Fußgängerweg entlang .
# Ground Truth: A woman in a black dress is pushing a cart with <unk> down a paved walkway .
# Prediction: A woman in a black dress is pushing a cart with a brick path on a stone path
# -----------------------------------
# Source Sentence: Ein Mann mit einer grauen Mütze , Trägershirt und schwarzen Shorts macht einen Handstand .
# Ground Truth: A man in a gray hat and tank top with black shorts doing a handstand .
# Prediction: A man in a gray hat , top and black shorts is doing a handstand . <eos>
# -----------------------------------
# Source Sentence: Zwei kurzhaarige Frauen stehen einander gegenüber und die blonde Frau spricht .
# Ground Truth: Two women with short hair are facing each other and the blond one is talking .
# Prediction: Two women women with each other are standing each other and the woman woman . <eos>
# -----------------------------------
# Source Sentence: Ein Mann starrt ein <unk> Paar an , während er den Häuserblock entlanggeht .
# Ground Truth: A man stare at a passing couple while walking down the block .
# Prediction: A man is looking at a plastic and he walking down the the street
# -----------------------------------
# Source Sentence: Zwei schwarze Hunde rennen auf beiden Seiten eines befestigten Weges
# Ground Truth: Two black dogs running down either side of a paved pathway
# Prediction: Two black dogs running on two side of a brick street .
# -----------------------------------
# Source Sentence: Ein Mann in einer <unk> spricht in ein Mikrofon .
# Ground Truth: A man in an army uniform speaks into a microphone .
# Prediction: A man in a dark - speaking is talking into a microphone
# -----------------------------------
# Source Sentence: Menschen verrichten <unk> und Gartenarbeiten in den Bereichen um den Fußgängerweg .
# Ground Truth: People landscaping and gardening the areas around the walkway .
# Prediction: People are are taking the and and are in the air
# -----------------------------------
# Source Sentence: Ein brauner Hund kaut auf einem großen Holzstück herum .
# Ground Truth: A brown dog chewing on a large piece of wood .
# Prediction: A brown dog is sitting around a large wooden . <eos>
# -----------------------------------
# Source Sentence: Eine Frau in einer gelben Jacke folgt zwei anderen Frauen .
# Ground Truth: A woman in a yellow jacket following two other women .
# Prediction: A woman in a yellow jacket is two two women . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer stehen auf der mit Graffiti bedeckten Straße .
# Ground Truth: Two men are standing on the street covered in graffiti .
# Prediction: Two men are standing on the graffiti with graffiti . <eos>
# -----------------------------------
# Source Sentence: Ein Mann in einem blauen Hemd bläst auf einer Trompete .
# Ground Truth: A man in a blue shirt blowing a trumpet .
# Prediction: A man in a blue shirt is blowing on a field
# -----------------------------------
# Source Sentence: Eine große Gruppe von Menschen sieht einem Künstler auf einer Bühne zu .
# Ground Truth: A large group of people watching a performer on a stage .
# Prediction: A large group of people are on a stage on a stage .
# -----------------------------------
# Source Sentence: Eine Frau und ihre zwei Kinder sind am Strand und die Frau springt hoch in die Luft .
# Ground Truth: A woman and her two kids are on the beach and the woman is leaping high into the air .
# Prediction: A woman and her two children are jumping up in the air at the beach . <eos>
# -----------------------------------
# Source Sentence: Ein Mann und eine Frau tauschen einen <unk> aus .
# Ground Truth: A man and woman are working on <unk> a bike tire tube .
# Prediction: A man and a woman are having a meal of a store . <eos>
# -----------------------------------
# Source Sentence: Ein Junge und ein Mann , die als <unk> verkleidet sind , stehen im Sand
# Ground Truth: A boy and a man dressed as rodeo clowns standing in sand
# Prediction: A boy and a man dressed as a crowd of a white uniform
# -----------------------------------
# Source Sentence: Ein Soldat der <unk> führt eine Gruppe anderer <unk> an , die die <unk> singen .
# Ground Truth: A national guard soldier leading a group of other national guard soldiers singing the national <unk> .
# Prediction: A military , performing a group of other other singing at the other . <eos>
# -----------------------------------
# Source Sentence: Zwei Fahrradfahrer fahren an Menschen vorbei die Straße entlang und unterhalten sich dabei .
# Ground Truth: Two bicyclists ride down the street past people while talking .
# Prediction: Two bicyclists are walking by the street while talking to talking .
# -----------------------------------
# Source Sentence: Drei Männer in Anzügen legen ihre Hände übereinander .
# Ground Truth: Three men in suits putting their hands together .
# Prediction: Three men in suits are their their hands on the
# -----------------------------------
# Source Sentence: Ein rotes Flugzeug fliegt über einem Boot und zieht dabei pinkfarbenen Rauch hinter sich her .
# Ground Truth: A red plane flying over a boat as it trails pink smoke .
# Prediction: A red airplane is over a boat pulling a red , behind it .
# -----------------------------------
# Source Sentence: Zwei Frauen in pinkfarbenen T-Shirts und Bluejeans unterhalten sich vor einem Bekleidungsgeschäft .
# Ground Truth: Two women wearing pink T - shirts and blue jeans converse outside clothing store .
# Prediction: Two women in pink shirts and blue jeans are talking in front of a store store
# -----------------------------------
# Source Sentence: Eine Frau mit einem gelben T-Shirt und Sonnenbrille geht einen Gehweg entlang .
# Ground Truth: A woman in a yellow t - shirt and sunglasses walks down a sidewalk .
# Prediction: A woman in a yellow shirt and sunglasses walks down a sidewalk . <eos>
# -----------------------------------
# Source Sentence: Eine ältere Frau verwendet einen rosafarbenen Regenschirm , um sich vor der Sonne zu schützen .
# Ground Truth: An elderly woman using a pink umbrella to shade herself from the sun .
# Prediction: An older woman is using a pink umbrella to her in the sun . <eos>
# -----------------------------------
# Source Sentence: Schwimmer in einem See werden von einem Jungen beobachtet , der auf einer Mauer sitzt .
# Ground Truth: Swimmers in a lake being watched by a boy sitting on a wall .
# Prediction: A group of a young boy are watching a boy sitting on a wall .
# -----------------------------------
# Source Sentence: Zwei Männer , von denen der eine schwarz und der andere weiß ist , stehen im Freien , spielen Gitarre und singen in ein Mikrofon .
# Ground Truth: Two men , one black and one white , play their guitars and sing into microphones as they stand outdoors .
# Prediction: Two men , one , black , and one , standing in front of the guitar . <eos>
# -----------------------------------
# Source Sentence: Zwei Frauen blicken auf viele Häuser hinab .
# Ground Truth: Two women look out at many houses below .
# Prediction: Two women looking out of many green . <eos>
# -----------------------------------
# Source Sentence: Eine Frau mit <unk> Gesicht reinigt den Boden ihres <unk> .
# Ground Truth: A <unk> faced woman cleans the floor of her living room .
# Prediction: A woman with a hair face is her the her 's 's her
# -----------------------------------
# Source Sentence: Eine Person fährt auf ihrem Geländemotorrad .
# Ground Truth: A person is riding his dirt bike .
# Prediction: A person is riding his dirt bike . <eos>
# -----------------------------------
# Source Sentence: Zwei Frauen betrachten ein Foto auf einer Kamera .
# Ground Truth: Two woman examine a photograph on a camera .
# Prediction: Two women are looking at a picture of a camera
# -----------------------------------
# Source Sentence: Zwei Frauen stehen vor einer Schulklasse und sprechen über ein Buch .
# Ground Truth: Two women are standing in front of a class of children talking about a book .
# Prediction: Two women stand in front of a class talking to a book . <eos>
# -----------------------------------
# Source Sentence: Ein Mann und zwei Frauen in Shorts gehen die Straße entlang .
# Ground Truth: One man and two women wearing shorts , walk down the street .
# Prediction: A man and two women walking in the white walk . <eos>
# -----------------------------------
# Source Sentence: Sie posieren für ein Bild .
# Ground Truth: They are posing for a picture .
# Prediction: A pose for a picture . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer sitzen um einen glänzenden Grill .
# Ground Truth: Two men sit around a shiny grill .
# Prediction: Two men are sitting around a small grill .
# -----------------------------------
# Source Sentence: Ein Junge übernimmt bei einem Rennen einen Stab von einem Mädchen .
# Ground Truth: A boy who is taking a stick from a girl in the middle of a race .
# Prediction: A boy is playing a pole from a girl in a race . <eos>
# -----------------------------------
# Source Sentence: Ein Fußballspieler in einem grünen Trikot läuft vom Spielfeld .
# Ground Truth: A soccer team player in a green shirt is running off the field .
# Prediction: A soccer player in a green uniform is running off the field . <eos>
# -----------------------------------
# Source Sentence: Männer in orangen Anzügen beobachten , wie eine Maschine in der Nähe von etwas gräbt , das wie <unk> aussieht .
# Ground Truth: Men in orange suits watching a machine dig near what looks to be subway tracks .
# Prediction: Men in orange suits watching as a machine in a wooden building , like like the other
# -----------------------------------
# Source Sentence: Vier Kinder sitzen auf einem <unk> und unterhalten sich .
# Ground Truth: 4 kids sit on a ledge and converse .
# Prediction: Four children are sitting on a wooden - conversation and
# -----------------------------------
# Source Sentence: Menschen gehen vor einer <unk> auf einem Gehweg in einer Großstadt .
# Ground Truth: People walk on a metropolitan sidewalk in front of a bar and grill .
# Prediction: People walking in a city city in front of a city city city . <eos>
# -----------------------------------
# Source Sentence: Ein Mann wird in einem Rollstuhl durch eine Bibliothek geschoben .
# Ground Truth: A man being pushed in a wheelchair through a library .
# Prediction: A man is being up into a library . <eos>
# -----------------------------------
# Source Sentence: Junge Erwachsene in einer geraden Linie , die rote , gelbe und schwarze T-Shirts tragen , führen einen Sketch auf .
# Ground Truth: Young adults wearing red , yellow , and black shirts in a straight line perform a sketch .
# Prediction: Young adults in a shopping line line red red , yellow , and black t - shirt . <eos>
# -----------------------------------
# Source Sentence: Drei Frauen rennen barfuß durch den Sand zum Wasser .
# Ground Truth: Three women run barefoot on the sand towards the water .
# Prediction: Three women are running on the sand with the other other .
# -----------------------------------
# Source Sentence: Ein Mann in einem gelben Oberteil , der vor einer kleinen <unk> steht , ist von oben durch ein <unk> zu sehen .
# Ground Truth: A man in a yellow top stand in front of a small shack , as viewed from above through wire mesh .
# Prediction: A man in a yellow shirt , is standing in front of a small boy of a white - stands . <eos>
# -----------------------------------
# Source Sentence: Der <unk> hört dem Arbeiter mit dem grünen Schutzhelm zu , während die zu <unk> Ausrüstung <unk> wird .
# Ground Truth: The FedEx driver listens to the workman in the green hard hat while the equipment to ship is being loaded .
# Prediction: The middle is listening to the workers with the green hard hat while he is equipment on it . <eos>
# -----------------------------------
# Source Sentence: Vier Jungen posieren , während ein Junge sein Getränk <unk> .
# Ground Truth: Four boys posing while one boy sets his drink down .
# Prediction: Four boys are posing while a boy is has his drink .
# -----------------------------------
# Source Sentence: Ein kleines Mädchen lächelt und streckt ihren Daumen nach oben , während sie vor einer Schildkröte posiert .
# Ground Truth: A young girl smiles and sticks her thumb up while posing in front of a turtle .
# Prediction: A little girl smiles and her up up up up while she in the front of a right
# -----------------------------------
# Source Sentence: Der <unk> Radfahrer <unk> um sein Leben , als konkurrierende <unk> von hinten <unk> .
# Ground Truth: The bike leader pedals for his life as competing countries gain his tail .
# Prediction: The bike bike is about to his beige , as the other is is from
# -----------------------------------
# Source Sentence: Drei Männer gehen auf einer Straße in den Bergen .
# Ground Truth: Three men are walking on a road in the mountains .
# Prediction: Three men are walking on the street in a road . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer in roten Gewändern führen eine <unk> durch .
# Ground Truth: Two men in red robes performing martial arts .
# Prediction: Two men in red robes are performing a dirt .
# -----------------------------------
# Source Sentence: Zwei Kinder tanzen bei einer Tanzaufführung .
# Ground Truth: Two kids dancing at a dance recital .
# Prediction: Two children are dancing at a football 's .
# -----------------------------------
# Source Sentence: Drei Männer unterhalten sich vor einer alten Treppe auf der Straße .
# Ground Truth: Three men are talking in front of old stairs on the street .
# Prediction: Three men are talking to front of an old stairs on the street .
# -----------------------------------
# Source Sentence: Mehrere Mädchen spielen mit Mehl .
# Ground Truth: Several girls are playing with flour .
# Prediction: Several girls are playing with snow . <eos>
# -----------------------------------
# Source Sentence: Ein Schlagzeuger und ein Gitarrist treten in einem dunklen Bereich auf .
# Ground Truth: A drummer and guitar player play a show in a dark area .
# Prediction: A male and a male performing in a dark area . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer beim Militär spielen Baseball .
# Ground Truth: Two men in the military are playing baseball .
# Prediction: Two men are performing in baseball . <eos>
# -----------------------------------
# Source Sentence: Eine Frau in <unk> Sportkleidung fährt Rollschuh .
# Ground Truth: A woman is rollerblading in a skimpy uniform .
# Prediction: A woman in a black outfit is suit . <eos>
# -----------------------------------
# Source Sentence: Der Tennisspieler trägt ein <unk> T-Shirt und ein blaues Stirnband .
# Ground Truth: The tennis player is wearing a yellow and blue shirt and a blue headband .
# Prediction: The tennis player is wearing a black and white - and red and <eos>
# -----------------------------------
# Source Sentence: Eine ältere Asiatin trägt eine Baskenmütze , eine Sonnenbrille , einen gelben Schal und eine <unk> Jacke .
# Ground Truth: An elderly Asian woman is wearing a beret , sunglasses , a yellow scarf , and a plaid jacket .
# Prediction: An older Asian woman is wearing a black , wearing sunglasses , a yellow scarf and a red and jacket jacket
# -----------------------------------
# Source Sentence: Ein Mann im mittleren Alter legt am Knie eines jüngeren <unk> , der auf einem <unk> sitzt , einen <unk> an .
# Ground Truth: A middle - aged man is taping up the knee of a younger football player who is sitting on a <unk> table .
# Prediction: A middle - aged man is laying on his knee , of a younger boy , sitting on a wooden - that is sitting
# -----------------------------------
# Source Sentence: Kinder fahren in einem Kettenkarussell
# Ground Truth: Kids are riding a swinging carnival ride
# Prediction: Children are riding in a ride . <eos>
# -----------------------------------
# Source Sentence: Ein Mann in einem weißen T-Shirt malt mitten auf einer mit Steinen gepflasterten Straße .
# Ground Truth: A man in a white t - shirt painting in the middle of a stone paved road .
# Prediction: A man in a white t - shirt is standing in the middle of the road with rocks .
# -----------------------------------
# Source Sentence: Ein Verkäufer sitzt inmitten seines <unk> auf einem Straßenmarkt in einem asiatischen Land .
# Ground Truth: A vendor sits in the middle of a display of glasses at a street market in an Asian country .
# Prediction: A vendor is sitting in the Asian 's 's 's in a Asian country . <eos>
# -----------------------------------
# Source Sentence: Zwei junge Männer in Bluejeans und Turnschuhen überqueren eine städtische Straße .
# Ground Truth: Two young men in blue jeans and sneakers cross an urban street .
# Prediction: Two young men in blue jeans and are cross a city street . <eos>
# -----------------------------------
# Source Sentence: Ein Geländewagen versucht , aus einem Graben <unk> .
# Ground Truth: An ATV attempts to get out of a ditch .
# Prediction: An An is trying to trying out of a lab .
# -----------------------------------
# Source Sentence: Ein Mann singt in ein Mikrofon , während seine Band spielt .
# Ground Truth: A man is singing into a microphone while his band plays .
# Prediction: A man is singing into a microphone while his band is playing .
# -----------------------------------
# Source Sentence: Ein Herr kommt aus einem Waschsalon .
# Ground Truth: A gentleman coming out of a laundromat .
# Prediction: A gentleman is out out at a mat .
# -----------------------------------
# Source Sentence: Ein Mann mit einem <unk> sitzt an einem Springbrunnen und beobachtet die Menschen der Stadt .
# Ground Truth: One man , wearing a hooded sweatshirt , sitting at a fountain watching the people of the city .
# Prediction: A man with a red - sits sits at a fountain fountain while people in the city . <eos>
# -----------------------------------
# Source Sentence: <unk> stehen oben an einer <unk> , die auf ein großes Schiff führt .
# Ground Truth: <unk> stand at the top of a <unk> to a large boat .
# Prediction: A stand standing on a brick - building , a performing on a large
# -----------------------------------
# Source Sentence: Zwei Eishockeyspieler sind bereit für das Spiel , während der Schiri neben ihnen im Begriff ist , den Puck zu werfen .
# Ground Truth: Two hockey players ready to start the game with the ref by them about to drop the puck .
# Prediction: Two hockey hockey are getting ready to the game , with the other is standing next to the ball .
# -----------------------------------
# Source Sentence: Ein Mann im weißen Hemd macht <unk> .
# Ground Truth: A man in a white shirt is making shish kabob .
# Prediction: A man in a white shirt is doing a piece of his
# -----------------------------------
# Source Sentence: Ein schwarzer Mann mit weißem T-Shirt und schwarzen Kappe sitzt auf dem Bordstein und schreibt Textnachrichten .
# Ground Truth: A <unk> male in a white t - shirt and a black hat sitting on the curb texting .
# Prediction: A black man in a white t - shirt and black cap is sitting on the curb , writing .
# -----------------------------------
# Source Sentence: Zwei Männer ringen auf einem gelb-blauen Boden .
# Ground Truth: Two man are wrestling on a yellow and blue floor .
# Prediction: Two men are wrestling on a yellow and yellow ground . <eos>
# -----------------------------------
# Source Sentence: Footballspieler haben Schwierigkeiten , bei ihren <unk> durch die <unk> Linie zu <unk> .
# Ground Truth: Football players struggle to get plays through a tough line .
# Prediction: A group of boys are their their out of the water line
# -----------------------------------
# Source Sentence: Ein Junge mit Brille und einem leuchtend gelben T-Shirt steht auf einem Parkplatz .
# Ground Truth: A boy with glasses wearing a bright yellow shirt is standing in a parking lot .
# Prediction: A boy with glasses and a bright yellow shirt is standing on a parking lot . <eos>
# -----------------------------------
# Source Sentence: Ein Mann mit einer <unk> , der keine Beine hat , geht neben einem anderen Mann , der zu einem Marathon <unk> ist .
# Ground Truth: A man with a <unk> who does n't have legs is walking with another man who is <unk> into a marathon .
# Prediction: A man with a red hat , with his legs legs is walking to a man in a marathon . <eos>
# -----------------------------------
# Source Sentence: Ein Mann mit beginnender Glatze und roter Sonnenbrille in einem grünen Hemd steht vor einem Gebäude .
# Ground Truth: A balding man in red sunglasses wearing a green shirt standing in front of a building .
# Prediction: A man with a man is wearing a red shirt is standing in front of a building .
# -----------------------------------
# Source Sentence: Einige Menschen schwimmen in einem Gewässer .
# Ground Truth: Several people swim in a body of water .
# Prediction: Some people are swimming in a body of water .
# -----------------------------------
# Source Sentence: Ein Junge mit einem Irokesenschnitt jagt Gänse in einem Park .
# Ground Truth: A boy with a Mohawk chasing geese in a park .
# Prediction: A boy with a toy is chasing in a park . <eos>
# -----------------------------------
# Source Sentence: Ein <unk> Auto , das von vielen <unk> <unk> wird .
# Ground Truth: A <unk> car with many firefighters cutting into the car .
# Prediction: A man car car by many of people . <eos>
# -----------------------------------
# Source Sentence: Ein Mädchen sitzt in bequemer Haltung an einem öffentlichen Ort und liest ein Buch , das sie mit ihrer Hand geöffnet hält , an der sich ein Ring mit einem Schmetterling befindet .
# Ground Truth: Sitting casually in a public place , a girl reads holding the book open with her hand on which is a butterfly ring .
# Prediction: A girl sits in a public place while reading a book , is holding her a girl in her hand . <eos>
# -----------------------------------
# Source Sentence: Ein Mann in einem grauen Hemd legt seinen Kopf auf einen Tisch .
# Ground Truth: A man wearing a gray shirt resting his head on a table .
# Prediction: A man in a gray shirt is laying his head on a table .
# -----------------------------------
# Source Sentence: Von Touristen <unk> Bilder bei einem Gebäude in China .
# Ground Truth: Tourist taken pictures at a building in China .
# Prediction: A couple of pictures of their at a building .
# -----------------------------------
# Source Sentence: Eine Frau mit lilafarbenen Haaren und ein Mann in <unk> <unk> .
# Ground Truth: A woman with purple hair and a man in military <unk> .
# Prediction: A woman with purple hair and a man in a black - dress
# -----------------------------------
# Source Sentence: <unk> in Uniformen marschieren in einer Parade und spielen dabei <unk> Instrumente .
# Ground Truth: <unk> in uniforms march in a parade while playing flute - like instruments .
# Prediction: A group in uniforms are riding in a parade playing playing instruments . <eos>
# -----------------------------------
# Source Sentence: Die Straße ist voller Menschen , die Jacken tragen .
# Ground Truth: The street is crowded with many people with coats on .
# Prediction: The street is full of jackets . <eos>
# -----------------------------------
# Source Sentence: Eine Frau bereitet die Zutaten für einen Suppentopf vor .
# Ground Truth: A woman prepares ingredients for a bowl of soup .
# Prediction: A woman is preparing the meat for a food . <eos>
# -----------------------------------
# Source Sentence: Ein Kind sitzt in einer Menschenmenge auf den Schultern seines Vaters .
# Ground Truth: A child sitting on her dad 's shoulders in a crowd .
# Prediction: A child sits on the shoulders 's at a young at his shoulders
# -----------------------------------
# Source Sentence: Mehrere Menschen genießen eine Zigarette bei einem Aschenbecher .
# Ground Truth: Several people are enjoying a cigarette near an ashtray .
# Prediction: Several people enjoying a cigarette at an outdoor . <eos>
# -----------------------------------
# Source Sentence: Ein Mann in einer grünen Jacke lächelt .
# Ground Truth: A man in a green jacket is smiling .
# Prediction: A man in a green jacket smiles . <eos>
# -----------------------------------
# Source Sentence: Zwei Chinesen stehen an einer Wandtafel .
# Ground Truth: Two chinese people are standing by a chalkboard .
# Prediction: Two people are standing at a board . <eos>
# -----------------------------------
# Source Sentence: Ein Mann und mehrere Frauen sehen Milchkästen voll mit <unk> oder Bildern durch , die zum Verkauf stehen .
# Ground Truth: Man and women look through milk crates full of records or pictures on sale .
# Prediction: A man and several women are standing and of full of the or or are are
# -----------------------------------
# Source Sentence: Zwei einander zugewandte Menschen spielen ein Spiel .
# Ground Truth: Two people playing a game facing each other .
# Prediction: Two other are are playing volleyball people playing a game
# -----------------------------------
# Source Sentence: Ein Mann mit einem blauen Rucksack liest die Zeitung , während er auf die U-Bahn wartet .
# Ground Truth: A man with a blue backpack reads the paper while waiting to board the subway .
# Prediction: A man with a blue backpack reads the newspaper while he is waiting for the subway .
# -----------------------------------
# Source Sentence: Ein Mann schläft in einem grünen Raum auf einem Sofa .
# Ground Truth: A man sleeping in a green room on a couch .
# Prediction: A man is sleeping in a green room on a couch .
# -----------------------------------
# Source Sentence: Blonder Mann in einer schwarzen <unk> formt eine Skulptur .
# Ground Truth: Blond - haired man wearing a black fleece jacket sculpting .
# Prediction: A man with black black is making a sculpture . <eos>
# -----------------------------------
# Source Sentence: Ein Mann und eine Frau unterhalten sich , während sie neben einem Baum stehen .
# Ground Truth: A man and a woman talk while standing next to a tree .
# Prediction: A man and a woman are talking while they next to a tree .
# -----------------------------------
# Source Sentence: Mann und Junge spielen bei Sonnenuntergang mit einem Hund am Strand .
# Ground Truth: Man and boy play with dog at sunset on a beach .
# Prediction: Man and boy playing at a beach at a beach . <eos>
# -----------------------------------
# Source Sentence: Ein Kassierer mit einem schwarzen <unk> <unk> <unk> .
# Ground Truth: A cashier with a black <unk> sweatshirt is counting change .
# Prediction: A man with a black black - is is is is .
# -----------------------------------
# Source Sentence: Ein Mann in Shorts redet vor einer Spüle mit einem anderen Mann in Bluejeans .
# Ground Truth: One man in shorts is talking to another man in blue jeans in front of a sink .
# Prediction: A man in shorts is talking to a man in blue jeans in a blue blue . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von <unk> geht mit amerikanischen Flaggen und anderen <unk> die Straße entlang .
# Ground Truth: A group of <unk> walking down the road with american flags and other military flags .
# Prediction: A group of people are walking in front of them flags and Asian flags are walking down
# -----------------------------------
# Source Sentence: Ein Mann führt zwei kleine <unk> in einem Park spazieren .
# Ground Truth: A man is leading two small <unk> on a walk at a park .
# Prediction: A man is two two small small in a park . <eos>
# -----------------------------------
# Source Sentence: Läufer passieren einen <unk> in der Stadt .
# Ground Truth: Runners pass a check point in the city .
# Prediction: A race of the race is a city in the
# -----------------------------------
# Source Sentence: Menschen in einer Schlange machen sich bereit , um in einen Bus zu steigen .
# Ground Truth: People in line getting ready to board a bus .
# Prediction: People are line to get to get on a bus .
# -----------------------------------
# Source Sentence: Zwei Kinder spielen auf einem Klettergerüst .
# Ground Truth: Two children playing on a jungle gym .
# Prediction: Two children are playing on a gym gym .
# -----------------------------------
# Source Sentence: Eine Mutter und zwei Kinder posieren mit lustigen Gesichtern .
# Ground Truth: A mother and two children are posing with funny faces .
# Prediction: A mother and two children are posing with some face - face
# -----------------------------------
# Source Sentence: Ein Golden Labrador schwimmt mit einem roten Spielzeug im Maul durch das Wasser .
# Ground Truth: A Golden Labrador is swimming through water with a red toy in its mouth .
# Prediction: A golden lab swimming with a red toy in its mouth in the mouth . <eos>
# -----------------------------------
# Source Sentence: Eine Frau trägt <unk> auf , während ein Junge mit Irokesenschnitt einen Spiegel hält .
# Ground Truth: A woman applies face paint while a boy with a Mohawk holds a mirror .
# Prediction: A woman is wearing a red - on a white , holding a boy with a
# -----------------------------------
# Source Sentence: Ein Mann mit Sonnenbrille hilft einem Kind mit Sonnenbrille eine Rutsche herunterzurutschen .
# Ground Truth: A man with sunglasses is helping a child with sunglasses slide down a slide .
# Prediction: A man in sunglasses is a woman with sunglasses is a slide . <eos>
# -----------------------------------
# Source Sentence: Vier wie <unk> aussehende Menschen gehen eine Straße mit Bäumen im Hintergrund entlang
# Ground Truth: Four <unk> looking people walking down a street with trees in the background
# Prediction: Four people are looking at people walking down a street with trees in the
# -----------------------------------
# Source Sentence: Eine Frau mit lilafarbenem Oberteil und weißem Rock sieht sich einen <unk> an .
# Ground Truth: A lady in a purple top and a white skirt is watching a marching parade .
# Prediction: A woman in a purple shirt and white skirt looks at a glass . <eos>
# -----------------------------------
# Source Sentence: Eine Frau , die eine Einkaufstasche von Trader Joe's trägt , ist im Zug eingeschlafen .
# Ground Truth: A woman carrying a Trader Joe 's grocery bag has fallen asleep on the train .
# Prediction: A woman carrying a shopping bag is holding a cart cart is has her on the train
# -----------------------------------
# Source Sentence: Eine Ureinwohnerin arbeitet an einer Handarbeit .
# Ground Truth: A native woman is working on a craft project .
# Prediction: A woman is working on a art - art . <eos>
# -----------------------------------
# Source Sentence: Eine ältere Frau mit einer blauen Mütze sitzt auf dem Gehweg und hackt etwas Gelbes auf einem Brett neben sich .
# Ground Truth: An elderly woman wearing a blue hat is sitting on the sidewalk chopping something yellow on a board beside her .
# Prediction: An older woman in a blue hat is sitting on the sidewalk and wood something in a board next to . <eos>
# -----------------------------------
# Source Sentence: Eine brünette Frau steht auf dem Gehweg und blickt die Straße hinunter .
# Ground Truth: A brunette woman is standing on the sidewalk looking down the road .
# Prediction: A brown woman standing on the sidewalk looking at the street . <eos>
# -----------------------------------
# Source Sentence: Ein kleiner Junge und ein Mädchen lachen miteinander , während das Mädchen ein Handzeichen macht .
# Ground Truth: A young boy and girl are laughing together as the girl holds up a hand sign .
# Prediction: A little boy and a girl are laughing while the girl is a ball in a white .
# -----------------------------------
# Source Sentence: Ein Mann in einem grauen T-Shirt ruht sich aus .
# Ground Truth: A man in a gray t - shirt rests .
# Prediction: A man in a gray t - shirt is relaxing .
# -----------------------------------
# Source Sentence: Zwei Radfahrer überqueren die Straße an einem sehr windigen Tag in Kalifornien .
# Ground Truth: Two cyclists cross the street on a very <unk> California day .
# Prediction: Two bicyclists are crossing the street on a very tree day in their
# -----------------------------------
# Source Sentence: Da sind viele Menschen in einem Gebäude und ein paar Menschen kochen etwas zu essen .
# Ground Truth: There are many people in a building with some people cooking food .
# Prediction: There are many people in a building and some people are eating food .
# -----------------------------------
# Source Sentence: Eine Gruppe junger Menschen posiert in der Luft an einem Sandstrand .
# Ground Truth: A group of young people posing in the air on a sandy beach .
# Prediction: A group of young people posing in a air on a beach beach . <eos>
# -----------------------------------
# Source Sentence: Polizist <unk> mit einem Mann , der eine Hand in die Luft streckt , während andere Polizisten zusehen .
# Ground Truth: <unk> wrestle one man with his hand sticking up in the air as other cops watch .
# Prediction: A police man with a man holding the air while the other police watch . <eos>
# -----------------------------------
# Source Sentence: Menschen gehen auf einem Gehweg , an dem ein Freiluftmarkt stattfindet .
# Ground Truth: People are walking down a sidewalk where there is an outdoors market .
# Prediction: People walking on a sidewalk in an open open open . <eos>
# -----------------------------------
# Source Sentence: Zwei Mädchen gehen eine Straße entlang .
# Ground Truth: Two girls walking down the street .
# Prediction: Two girls walking down a street . <eos>
# -----------------------------------
# Source Sentence: <unk> blicken auf ein Herz , das von einem <unk> am Himmel <unk> wurde .
# Ground Truth: Beach goers look at a heart left in the sky by a sky writer .
# Prediction: A look at a very , from from a back in the sky . <eos>
# -----------------------------------
# Source Sentence: Ein fröhlicher Mann hebt eine <unk> Frau hoch .
# Ground Truth: A man picks up a <unk> wet woman happily .
# Prediction: A happy man is holding up a plastic of a woman
# -----------------------------------
# Source Sentence: Ein Mann und zwei Kinder überqueren eine Straße .
# Ground Truth: A man and two children crossing a street .
# Prediction: A man and two children are crossing a street .
# -----------------------------------
# Source Sentence: Ein kleines Kind spielt unter einem Rasensprenger .
# Ground Truth: A young child is playing in a water sprinkler .
# Prediction: A young child playing playing a grassy - grassy . <eos>
# -----------------------------------
# Source Sentence: Das <unk> an Bananen , Orangen , Melonen <unk> eines asiatischen Obst- und <unk> auf seinem kleinen Boot .
# Ground Truth: An Asian fruit and vegetable vendor 's selection of bananas , oranges , melons and more in his small boat .
# Prediction: The middle of the Chinese of people , , is , is wearing a Asian market and is on his small boat
# -----------------------------------
# Source Sentence: Eine Gruppe von Menschen sitzt draußen an einem Tisch , trinkt etwas und unterhält sich .
# Ground Truth: A group of people are sitting at a table outside having drinks and talking .
# Prediction: A group of people are sitting outside a table drinking something and talking . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer mit <unk> sprechen miteinander auf einem Freiluftmarkt .
# Ground Truth: Two men in <unk> 's have a discussion in an outdoor market .
# Prediction: Two men with their gear are talking to a other in an open market
# -----------------------------------
# Source Sentence: Zwei Kinder springen auf einem abgeschirmten blau-schwarzen Trampolin , das von Bäumen umgeben ist .
# Ground Truth: Two children jumping on a screened in blue and black trampoline while outside surrounded by trees .
# Prediction: Two children are jumping on a subway blue and blue blue and one surrounded by trees . <eos>
# -----------------------------------
# Source Sentence: Eine Menschenmenge steht auf der Straße vor einer Reihe weißer Zelte .
# Ground Truth: A crowd of people stand in street in front of a series of white tents .
# Prediction: A crowd of people standing on the street in front of a line of white white .
# -----------------------------------
# Source Sentence: Ein Mann in einer blauen Jacke wird auf seinem Schlitten von zwei Hunden gezogen .
# Ground Truth: A man in a blue coat is <unk> on his sled by two dogs .
# Prediction: A man in a blue jacket is being being by his dogs by his dogs .
# -----------------------------------
# Source Sentence: Eine Person mit Hut und Schal blickt nach rechts .
# Ground Truth: A person wearing a hat and scarf looks to the right .
# Prediction: A person in a hat and a looks looks at the right .
# -----------------------------------
# Source Sentence: Ein kleines Mädchen streckt die Hand aus , um ein Reh zu streicheln .
# Ground Truth: Young girl reaches out to pet a deer .
# Prediction: A little girl is holding her from to a younger
# -----------------------------------
# Source Sentence: Ein junger Mann stellt <unk> auf einem <unk> mit lilafarbenem <unk> auf .
# Ground Truth: A young man sets up pool balls , on a purple <unk> billiard .
# Prediction: A young man is putting up on a wooden - purple purple purple . <eos>
# -----------------------------------
# Source Sentence: Bauarbeiter stehen auf einer Maschine
# Ground Truth: Construction workers standing on top of a piece of machinery .
# Prediction: Construction workers are standing on a machine . <eos>
# -----------------------------------
# Source Sentence: Drei Mädchen reiten auf Pferden , wobei sich das <unk> Mädchen im Fokus befindet .
# Ground Truth: Three girls are horseback riding with the focus on the <unk> girl .
# Prediction: Three girls are riding horses on the other , one is in the their
# -----------------------------------
# Source Sentence: Eine Gruppe von Menschen läuft bei einem Marathon im Winter .
# Ground Truth: A group of people running a marathon in the winter .
# Prediction: A group of people walking in a marathon in the winter .
# -----------------------------------
# Source Sentence: Ein Kind sitzt auf einer Gesteinsformation .
# Ground Truth: A child sitting on a rock formation .
# Prediction: A child is sitting on a rock rock .
# -----------------------------------
# Source Sentence: Ein Heißluftballon landet mit dem Schatten eines Mannes im Hintergrund .
# Ground Truth: A hot air balloon touching down with a man 's shadow in the background .
# Prediction: A hot balloon is with the shade of a man in the background . <eos>
# -----------------------------------
# Source Sentence: Ein Hund geht mit einem Tuch im Maul durch einen kleinen Bach .
# Ground Truth: A dog walking through a small stream with a rag in his mouth .
# Prediction: A dog is walking through a small stream in its mouth through a small stream
# -----------------------------------
# Source Sentence: Eine Mutter mit einer blauen Baskenmütze und blauen Schuhen und ihren zwei Söhnen .
# Ground Truth: A mother in a blue beret and blue shoes with her two sons .
# Prediction: A mother with a blue skirt and blue shoes and her two students . <eos>
# -----------------------------------
# Source Sentence: Bei einer Art Jahrmarkt stellt ein Mann Zuckerwatte her .
# Ground Truth: At some sort of carnival , a man is making cotton candy .
# Prediction: A group of some sort of a group of metal . <eos>
# -----------------------------------
# Source Sentence: Das kleine Mädchen mit dem grünen Halsband rennt weg vom Netz .
# Ground Truth: The little girl with the green necklace is running away from the net .
# Prediction: The little girl with the green collar is walking away from the net . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von Kindern sitzt hinten in einem Van und sieht sich ein Buch an .
# Ground Truth: A group of kids sitting in the back of a van together looking at a book .
# Prediction: A group of children sitting in a van looking at a book . <eos>
# -----------------------------------
# Source Sentence: Ein <unk> und eine <unk> untersuchen einen sehr großen Tiger , der auf dem Boden liegt .
# Ground Truth: A man and woman <unk> checking on a very large tiger laying on the ground .
# Prediction: A man and a woman is standing at a very large building that on the ground .
# -----------------------------------
# Source Sentence: Eine Frau in weißer Tenniskleidung springt hoch , um den Ball zu schlagen .
# Ground Truth: A woman in a white tennis outfit is jumping up to hit the ball .
# Prediction: A woman in white is tennis jumping up to hit the ball . <eos>
# -----------------------------------
# Source Sentence: Eine Mutter und ihr Sohn lächeln , während sie den Hügel <unk> .
# Ground Truth: A mother and son smiling as they sled downhill .
# Prediction: A mother and her son smiling as they are the the
# -----------------------------------
# Source Sentence: <unk> Gruppe von Erwachsenen bei einer Zusammenkunft , ein Mann mit einer Tätowierung wirft etwas .
# Ground Truth: <unk> group of adults at a gathering , one man with tattoos is throwing something .
# Prediction: A group of adults at a outdoor , one man with a tattoo is throwing something .
# -----------------------------------
# Source Sentence: Eine Gruppe kampiert in einer einsamen Gegend .
# Ground Truth: A group camps in a desolate area .
# Prediction: A group of people are in an empty area
# -----------------------------------
# Source Sentence: Drei Kinder in braunen Shirts und Jeans hüpfen im Freien mit Blättern auf dem Boden .
# Ground Truth: Three kids wearing brown shirts and jeans jumping outdoors with leaves on the ground .
# Prediction: Three children in brown shirts and jeans jumping in the ground with leaves in the ground
# -----------------------------------
# Source Sentence: Eine Band spielt bei einem Konzert Musik auf einer Bühne .
# Ground Truth: A band is playing music on stage at a concert .
# Prediction: A band playing music on a concert at a concert . <eos>
# -----------------------------------
# Source Sentence: Ein Mann und eine Frau fischen am Strand .
# Ground Truth: A man and woman fishing at the beach .
# Prediction: A man and a woman fishing at the beach .
# -----------------------------------
# Source Sentence: Ein Mann rollt einen runden Tisch über den Boden .
# Ground Truth: A man is rolling a circular table across the floor .
# Prediction: A man is a long cart over over the ground . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von Mädchen spielt in einem Springbrunnen in der Sonne .
# Ground Truth: A group of girls are playing in a water fountain in the sun .
# Prediction: A group of girls playing in a fountain fountain . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von Menschen in einem Boot auf einem großen Gewässer .
# Ground Truth: A group of people are in a boat on a large body of water .
# Prediction: A group of people in a boat on a large body of water . <eos>
# -----------------------------------
# Source Sentence: Ein Mann mit <unk> und einem Helm reitet auf einem weißen Pferd und das Pferd springt über ein Hindernis .
# Ground Truth: A man wearing riding boots and a helmet is riding a white horse , and the horse is jumping a hurdle .
# Prediction: A man with a red and riding rides a skateboard and a horse is jumping over a hurdle . <eos>
# -----------------------------------
# Source Sentence: Einige Männer auf einem Boot oder Schiff scheinen etwas zu besprechen .
# Ground Truth: Some men appear to be discussing something on a boat or ship .
# Prediction: Some men on a boat or what to be something to be . <eos>
# -----------------------------------
# Source Sentence: Drei kleine Hunde schnüffeln an etwas .
# Ground Truth: Three small dogs <unk> at something .
# Prediction: Three small dogs are are something something .
# -----------------------------------
# Source Sentence: Ein Mädchen mit blauen <unk> sitzt am Straßenrand .
# Ground Truth: A girl with blue dreadlocks is sitting on the side of the road .
# Prediction: A girl with blue blue shirt is sitting on the side . <eos>
# -----------------------------------
# Source Sentence: Ein kleines Baby mit einer rosafarbenen Mütze liegt <unk> da und schläft .
# Ground Truth: A little baby in a pink hat lying naked and sleeping .
# Prediction: A little baby with a pink hat is laying down and sleeping .
# -----------------------------------
# Source Sentence: Die Menschen sind <unk> in mehrere Schichten gekleidet und machen gemeinsame Bewegungen .
# Ground Truth: The people are dressed in heavy layered clothing , and are motioning together .
# Prediction: The people are walking in several of up and take are are about to .
# -----------------------------------
# Source Sentence: Eine Frau und ein kleines Kind haben Spaß bei einem Brettspiel .
# Ground Truth: A woman and a young child has fun while playing a board game .
# Prediction: A woman and a young child having a game at a game game . <eos>
# -----------------------------------
# Source Sentence: Mutter und Tochter in <unk> posieren für ein Foto .
# Ground Truth: Mother and daughter wearing <unk> in <unk> customs are posing for a picture .
# Prediction: A mother and daughter in a pose pose for a picture . <eos>
# -----------------------------------
# Source Sentence: Eine Frau in einem grünen Shirt geht eine belebte Straße entlang .
# Ground Truth: A woman in a green shirt is walking down a crowded street .
# Prediction: A woman in a green shirt is walking down a crowded street . <eos>
# -----------------------------------
# Source Sentence: Junge Frauen und Kinder in einem Dorf , wobei eine einzelne Frau in die Kamera blickt .
# Ground Truth: Young women and children in a village , with a single woman focused on the camera .
# Prediction: Young women and children in a light , one a red woman in the camera . <eos>
# -----------------------------------
# Source Sentence: Zwei Menschen fahren mit dem Fahrrad auf einer unbefestigten Straße
# Ground Truth: Two people are riding their bicycles on a dirt road
# Prediction: Two people are riding a bike on a dirt road .
# -----------------------------------
# Source Sentence: Dem jungen Mädchen werden von dem kleinen Jungen hinter ihr Hasenohren gemacht .
# Ground Truth: The young girl is given rabbit ears by the young boy behind her .
# Prediction: A young girl is being being being by them as her arms . <eos>
# -----------------------------------
# Source Sentence: Die Frau mit einem schwarzen Hut macht ein Foto bei Schneefall .
# Ground Truth: The lady wearing a black hat is taking a picture while the snowfalls .
# Prediction: The woman in a black hat is taking a picture at the day day .
# -----------------------------------
# Source Sentence: Ein Mann mit einem braunen Hemd , einer grauen Weste und einer schwarzen Mütze spielt <unk> .
# Ground Truth: A man with a brown shirt , gray vest and black cap plays an electric bass .
# Prediction: A man in a brown shirt , gray a black vest and black hat is playing the other
# -----------------------------------
# Source Sentence: Der kleine braune Hund befindet sich inmitten der Topfpflanzen und heruntergefallenen Blätter .
# Ground Truth: The small brown dog is amidst the potted plants and fallen leaves .
# Prediction: The little brown dog is running in the middle of the green and leaves
# -----------------------------------
# Source Sentence: Ein Mann schlägt gerade einen rot-weiß-blauen Volleyball .
# Ground Truth: A man is in the middle of hitting a red , white and blue volleyball .
# Prediction: A man is playing a red and red and white and white volleyball . <eos>
# -----------------------------------
# Source Sentence: Ein Mann greift nach oben , um an den Kabeln über einem Schreibtisch zu arbeiten .
# Ground Truth: A man reaches up to work with cables above a desk .
# Prediction: A man is looking to the to of a desk to a desk
# -----------------------------------
# Source Sentence: Schwarze Menschen sind in einem Lebensmittelgeschäft , um Essen zu kaufen .
# Ground Truth: Black people are at the grocery store to get there food .
# Prediction: A people are standing in a store store to food . <eos>
# -----------------------------------
# Source Sentence: Eine Frau nimmt mit ihrer Kamera ein Foto auf .
# Ground Truth: A woman is taking a picture with her camera .
# Prediction: A woman is holding a picture with her camera . <eos>
# -----------------------------------
# Source Sentence: Mann in weißem T-Shirt und gestreiften Shorts spielt Orgel und wird dabei von einem Mann in einem gelben T-Shirt beobachtet
# ...
# Ground Truth: A group of go - cart riders are racing around a go - cart track .
# Prediction: A group of people are are around around the side of the street . <eos>
# -----------------------------------
# Source Sentence: Vier Männer in T-Shirts und Shorts blicken aus einem Fenster auf die Straße hinunter .
# Ground Truth: Four men dressed in t - shirts and shorts are looking out a window <unk> the street below .
# Prediction: Four men in t - shirts and shorts looking out from a window on the street . <eos>
# -----------------------------------
# Source Sentence: Ein Mann in der Ferne bei einem <unk> Tempel .
# Ground Truth: A man off in the distance by a Buddhist temple .
# Prediction: A man in the distance at a crowd of a store .
# -----------------------------------
# Source Sentence: Ein Mann sitzt mit einem Bier in der Hand auf einem Stuhl und brät an einem <unk> etwas zu essen .
# Ground Truth: A man sitting on a chair with a beer in his hands roasting something to eat on a wooden stick .
# Prediction: A man sits in a chair with a beer , while sitting at a chair table . <eos>
# -----------------------------------
# Source Sentence: Zwei Männer sind an einem hellen , sonnigen Tag unterwegs , um ein paar Fische im See zu fangen .
# Ground Truth: Two men are out on a bright , sunny day attempting to catch some fish on the lake .
# Prediction: Two men are on a bright sunny day , some some fish in the lake . <eos>
# -----------------------------------
# Source Sentence: Ein weißer Hund mit braunen Flecken springt vom Ufer aus in das Wasser .
# Ground Truth: A white dog with brown marks jumps from the bank into the water .
# Prediction: A white dog with brown brown jumping is jumping from the water from the water
# -----------------------------------
# Source Sentence: Ein junger weißer Mann fegt eine Veranda mit einem großen Besen .
# Ground Truth: A young white male is sweeping a porch with a large broom .
# Prediction: A young white man is sweeping a porch with a large hoodie . <eos>
# -----------------------------------
# Source Sentence: Ein kleines Mädchen asiatischer Abstammung sitzt in einem schwarzen Eimer und isst mit einem breiten Lächeln im Gesicht ein <unk> .
# Ground Truth: A little girl of Asian descent , is sitting in a black bucket eating a <unk> , with a big smile on her face .
# Prediction: A little girl is dressed in a black bucket eating eating a table with a large smile in her face . <eos>
# -----------------------------------
# Source Sentence: Das Mädchen und der Junge küssen sich , während sie auf einer Holzbank sitzen .
# Ground Truth: The girl and boy are kissing whilst sitting on a wooden bench .
# Prediction: The girl and boy are kissing while sitting on a wooden bench . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von Freunden liegt ausgestreckt auf dem Boden und genießt die gemeinsame Zeit .
# Ground Truth: A group of friends lay sprawled out on the floor enjoying their time together .
# Prediction: A group of friends are laying out on the ground and enjoying the other . <eos>
# -----------------------------------
# Source Sentence: Eine Kellnerin in einem weißen T-Shirt bedient die Gäste in einem Restaurant .
# Ground Truth: A waitress in a white t - shirt serving guests at a restaurant .
# Prediction: A female in a white t - shirt is working the light in a restaurant
# -----------------------------------
# Source Sentence: Ein junger Skifahrer blickt in die Kamera .
# Ground Truth: A young skier looks at the camera .
# Prediction: A young skier is looking at the camera .
# -----------------------------------
# Source Sentence: Ein Mann und eine Frau posieren zusammen auf einer kopfsteingepflasterten Straße .
# Ground Truth: A man and woman pose together on a cobblestone street .
# Prediction: A man and a woman are together together on a street street
# -----------------------------------
# Source Sentence: Eine junge Frau spielt ein Saiteninstrument im Haus .
# Ground Truth: A young woman practices a string instrument indoors .
# Prediction: A young woman playing a instrument instrument in the house
# -----------------------------------
# Source Sentence: Ein Mann wartet am Bahnsteig auf den Zug .
# Ground Truth: A male is waiting for the train to arrive at the platform .
# Prediction: A man is waiting at the train platform on the train . <eos>
# -----------------------------------
# Source Sentence: Eine Person rudert in ihrem Boot im Wasser .
# Ground Truth: A person rowing in their boat in the water .
# Prediction: A person is in the boat with their boat in the
# -----------------------------------
# Source Sentence: Zwei Männer in einem fremden Land lächeln , wobei einer von ihnen steht und einer mit <unk> Beinen sitzt .
# Ground Truth: Two men in a foreign country smiling , one standing and one sitting with his legs crossed .
# Prediction: Two men in a foreign country smile while one of them is sitting and one with a red legs
# -----------------------------------
# Source Sentence: Ein Mann mit einer weißen Schürze und Hut verkauft Fleisch an einer belebten Straße .
# Ground Truth: A man in a white apron and hat is selling meat on a busy street .
# Prediction: A man in a white apron and hat is meat meat meat on a busy street .
# -----------------------------------
# Source Sentence: Eine Gruppe von Menschen in Schottenröcken , schwarzen Westen und Hemden mit weißem Kragen trommelt .
# Ground Truth: A group of people in plaid skirts , black vests and white - collared shirts are playing drums .
# Prediction: A group of people in a black black black and shirts shirts and white shirt . <eos>
# -----------------------------------
# Source Sentence: Ein Mann singt in ein Mikrofon und hält dabei eine Gitarre .
# Ground Truth: A man sings into a microphone while holding a guitar .
# Prediction: A man is singing into a microphone holding a guitar . <eos>
# -----------------------------------
# Source Sentence: Mehrere Männer beten , während sie am Ende eines Tisches mit Essen stehen .
# Ground Truth: Several men are praying while standing at the end of a table of food .
# Prediction: Several men are working while while standing stand to the table of a table with food
# -----------------------------------
# Source Sentence: Ein junger Mann holt sich an einem <unk> etwas zu essen .
# Ground Truth: A young man is getting something to eat at a <unk> concession stand .
# Prediction: A young man is getting food at a outdoor table . <eos>
# -----------------------------------
# Source Sentence: Ein <unk> wartet auf seinen nächsten Kunden .
# Ground Truth: A rickshaw <unk> waiting for his next <unk> .
# Prediction: A man is waiting for his next to his his
# -----------------------------------
# Source Sentence: Ein Junge in einem Park spielt mit zwei orangen Bällen .
# Ground Truth: A boy in a park playing with two orange balls .
# Prediction: A boy in a park playing with two orange balls . <eos>
# -----------------------------------
# Source Sentence: Ein großer schwarzer Hund rennt an einem Zaun entlang durch das Gras .
# Ground Truth: A large black dog runs along a fence in the grass .
# Prediction: A large black dog runs through the grass on a fence . <eos>
# -----------------------------------
# Source Sentence: Ein kleines Kind mit <unk> spielt in einem Reifen .
# Ground Truth: A toddler in a denim hats plays in a tire .
# Prediction: A young child with a red - plays is playing in a
# -----------------------------------
# Source Sentence: Hier sind zwei Mütter , die einem kleinen Kind zuhören .
# Ground Truth: Here are 2 moms listening to a toddler .
# Prediction: This are two two of the other to a child
# -----------------------------------
# Source Sentence: Ein Mädchen bei einem <unk> vollführt eine <unk> Übung und <unk> dadurch das Publikum .
# Ground Truth: A girl competing in gymnastics performs a <unk> routine as she <unk> the audience .
# Prediction: A girl in a sports uniform performing a piece of instrument and he is a crowd
# -----------------------------------
# Source Sentence: Eine Frau hält einen weiß-schwarzen Hund .
# Ground Truth: A woman holding a white and black dog .
# Prediction: A woman is holding a white and white dog .
# -----------------------------------
# Source Sentence: Ein Hund springt einem gelb-schwarzen Ball hinterher .
# Ground Truth: A dog jumps for a yellow and black ball .
# Prediction: A dog is jumping a blue and yellow ball . <eos>
# -----------------------------------
# Source Sentence: Eine bunt gekleidete Frau geht an einem weißen Lastwagen vorbei , der mit Flaschen gefüllt ist .
# Ground Truth: A woman in a colorful outfit is walking by a white truck filled with bottles .
# Prediction: A woman in a woman walking in a white truck past an glass of food . <eos>
# -----------------------------------
# Source Sentence: Eine Frau sitzt an einer dunklen Bar .
# Ground Truth: A woman sits at a dark bar .
# Prediction: A woman is sitting at a dark bar .
# -----------------------------------
# Source Sentence: Ein Hund springt in die Luft , um eine orange Frisbeescheibe zu fangen .
# Ground Truth: A dog is jumping in the air to catch an orange Frisbee .
# Prediction: A dog is jumping in the air to catch a orange Frisbee . <eos>
# -----------------------------------
# Source Sentence: Eine blonde Frau in einem blauen T-Shirt packt eine Mütze aus .
# Ground Truth: A blond - haired woman wearing a blue shirt unwraps a hat .
# Prediction: A blond woman in a blue shirt is is a piece of a hat
# -----------------------------------
# Source Sentence: Eine Frau in einem rotem Mantel , die eine vermutlich aus Asien <unk> Handtasche in einem blauen Farbton hält , springt für einen Schnappschuss in die Luft .
# Ground Truth: A lady in a red coat , holding a bluish hand bag likely of asian descent , jumping off the ground for a <unk> .
# Prediction: A woman in a red coat holding a woman of an woman in a blue - large city walks , jumping in a air . <eos>
# -----------------------------------
# Source Sentence: Ein Typ rennt vor einem schwarzen Bullen davon .
# Ground Truth: A guy is running away from a black bull .
# Prediction: A guy runs with a black bull . <eos>
# -----------------------------------
# Source Sentence: Ein Mann , der aussieht , als ob er geschlagen <unk> wäre , liegt vor <unk> <unk> auf dem Boden .
# Ground Truth: A man that looks like he has been hit is lying on the ground in front of some junk .
# Prediction: A man , looking as he is he is playing the ice , is laying on the ground in front of
# -----------------------------------
# Source Sentence: Menschen tanzen und klatschen in die Hände .
# Ground Truth: People are dancing and clapping there hands .
# Prediction: People dancing and their their their their . <eos>
# -----------------------------------
# Source Sentence: Ein Typ mit einem leuchtend grünen Kapuzenpullover überquert einen Fußgängerüberweg , während er zu einem Unfall zwischen ein paar Autos und einem Fahrrad blickt .
# Ground Truth: A guy in a bright green hoodie is crossing a crosswalk while looking at an accident between some cars and a bike .
# Prediction: A guy in a bright green green walking down a crosswalk while some people are walking around a large between cars and a bicycle
# -----------------------------------
# Source Sentence: Vier Männer stehen bei einem gelben Auto .
# Ground Truth: Four men standing near a yellow car .
# Prediction: Four men are standing in a yellow car .
# -----------------------------------
# Source Sentence: Eine fitte junge Frau übt Kickboxen mit einem roten Boxsack in einer Turnhalle .
# Ground Truth: A fit young woman is kickboxing with a red punching bag at a gym .
# Prediction: A young young woman is practicing a red bag with a red bag bag . <eos>
# -----------------------------------
# Source Sentence: Eine Gruppe von Polizisten steht vor einem Bus .
# Ground Truth: A bunch of police officers are standing outside a bus .
# Prediction: A group of police are standing in front of a bus .
# -----------------------------------
# Source Sentence: Ein Mann und eine Frau genießen ein Abendessen bei einer Feier .
# Ground Truth: A man and woman enjoying dinner at a party .
# Prediction: A man and a woman enjoying a meal at a party
# -----------------------------------
# Source Sentence: Eine Gruppe von drei Freunden unterhält sich in einem Haus .
# Ground Truth: A group of three friends are conversing inside of a home .
# Prediction: A group of three friends are talking in a house . <eos>
# -----------------------------------
# Source Sentence: Ein alter Mann läuft mit einem Ordner in der Hand herum
# Ground Truth: An old man walking with a folder in his hand
# Prediction: An old man walking with a body in a hand .
# -----------------------------------
# Source Sentence: Eine Frau steht auf einem Bein auf einer hohen Klippe und blickt über einen Fluss .
# Ground Truth: A woman standing on a high cliff on one leg looking over a river .
# Prediction: A woman is standing on a leg on a high cliff looking over a river .
# -----------------------------------
# Source Sentence: Ein Typ macht ein <unk> in einem Park .
# Ground Truth: A guy is doing a bike trick in a park .
# Prediction: A guy is doing a toy and a park . <eos>
# -----------------------------------
# Source Sentence: Ein Cowboy versucht bei einem Rodeo , ein Pferd zu bändigen , während das Pferd nach hinten <unk>
# Ground Truth: A cowboy <unk> a horse in a rodeo as the horse does a back kick
# Prediction: A cowboy is trying to be a horse as he horse the horse as the horse
# -----------------------------------
# Source Sentence: Drei Menschen sitzen im Freien an einem Tisch , an dem Kunstwerke lehnen .
# Ground Truth: Three people are sitting outside at a table with artwork leaning against it .
# Prediction: Three people are sitting outside a table outside of the art . <eos>
# -----------------------------------
# Source Sentence: Ein Kind kommt mit dem Snowboard zum Stehen
# Ground Truth: A child snowboarder coming to a stop
# Prediction: A child is walking to standing and standing
# -----------------------------------
# Source Sentence: Eine Gruppe schottischer Offiziere gibt eine Vorführung .
# Ground Truth: A group of Scottish officers doing a demonstration .
# Prediction: A group of people are are performing a performance .
# -----------------------------------
# Source Sentence: Ein Mann mit Brille und ein kleines Mädchen mit einer Schwimmweste schwimmen in einem Pool .
# Ground Truth: A man with glasses and a little girl with a life jacket swimming in a pool .
# Prediction: A man with glasses and a small girl in a life jacket swimming in a pool . <eos>
# -----------------------------------
# Source Sentence: Ein junges Mädchen läuft allein durch einen Park .
# Ground Truth: A young girl running by herself in a park .
# Prediction: A young girl is walking through a park . <eos>
# -----------------------------------
# Source Sentence: Ein Mann mit einem Namensschild sitzt in einem Stuhl .
# Ground Truth: A man with a name tag on is sitting in a chair .
# Prediction: A man with a mountain hill is sitting in a chair . <eos>
# -----------------------------------
# Source Sentence: Ein kleines barfüßiges Mädchen mit einem Helm geht über einen mit <unk> bedeckten umgefallenen Baum .
# Ground Truth: A young barefoot girl wearing a helmet walks down a mossy covered fallen down tree .
# Prediction: A little girl girl with a helmet walks over a tree covered covered . <eos>
# -----------------------------------
# Source Sentence: Ein Hund auf einem grasbewachsenen Feld blickt nach oben .
# Ground Truth: A dog in a grassy field , looking up .
# Prediction: A dog in a grassy field looking at the back .
# -----------------------------------
# Source Sentence: Ein junger , <unk> Fahrradfahrer in Blau wird bei der Fahrt über kleine Hügel in die Luft getragen .
# Ground Truth: A young helmeted biker in blue takes to the air while going over small hills .
# Prediction: A young , is riding bike on the race in the air . <eos>
# -----------------------------------
# Source Sentence: Mehrere Menschen unterhalten sich in einem Raum und verbringen Zeit miteinander .
# Ground Truth: Several people talking and spending time together in a room .
# Prediction: Several people are talking in a room with their time . <eos>
# Eval Loss= 4.5133

# %%
# save the state_dicts
torch.save(encoder.state_dict(), encoder_path)
torch.save(decoder.state_dict(), decoder_path)
torch.save(ba.state_dict(), ba_path)
